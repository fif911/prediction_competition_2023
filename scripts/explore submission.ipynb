# %%
import pandas as pd

cm_2018 = pd.read_parquet(
    '/Users/zakotianskyi/PycharmProjects/prediction_competition_2023/submission/boostrapped/cm/window=Y2018/bm_cm_bootstrap_expanded_2018.parquet')
cm_2018
# Out:
#                           outcome
# month_id country_id draw
# 457      1          0           0
#                     1           0
#                     2           0
#                     3          91
#                     4           0
# ...                           ...
# 468      246        995         0
#                     996         0
#                     997         0
#                     998         0
#                     999         0
#
# [2292000 rows x 1 columns]

# %%
# get draws for  month_id= 459 and country_id= 220
cm_2018[(cm_2018['month_id'] == 459) & (cm_2018['country_id'] == 70)].hist('outcome')
# Out:
# array([[<Axes: title={'center': 'outcome'}>]], dtype=object)

# %%
cm_2018[(cm_2018['month_id'] == 460) & (cm_2018['country_id'] == 220)].hist('outcome')
# Out:
# array([[<Axes: title={'center': 'outcome'}>]], dtype=object)
